# %% [markdown]
# ### Read and Write csv and xls file

# %%
import pandas as pd
df = pd.read_csv('https://gist.githubusercontent.com/bricedev/3513c6c87d5bdcb4fd8f/raw/0fced2498f4968f74e36454e46ade71d691dc62a/nyc.csv')
df
# Out:
#            date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0      2014-1-1                 1                 -2                -4
# 1      2014-1-2                 1                 -3                -8
# 2      2014-1-3                -8                -10               -13
# 3      2014-1-4                -2                 -7               -13
# 4      2014-1-5                 4                  1                -3
# ..          ...               ...                ...               ...
# 360  2014-12-27                13                 10                 7
# 361  2014-12-28                12                  9                 6
# 362  2014-12-29                 7                  4                 1
# 363  2014-12-30                 1                 -1                -2
# 364  2014-12-31                 0                 -1                -3
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# ...

# %%
# read excel file
# df = pd.read_excel('weatherdata.xls')

# %% [markdown]
# ### GROUP-BY

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/pramit026/ML-AI-NOTES/main/01.%20AppliedAI_NOTES/7.%20Pandas/weather_data_cities.csv?token=GHSAT0AAAAAABTAI3BAUVCQOFSUMJZU67XKYSPRMWQ')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
gr = df.groupby('city')
gr

# %%
for city, city_df in gr:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
# getting specific group
gr.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
# find the max temp in all cities
print(gr.max())
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
print(gr.mean())
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
print(gr.describe())
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %% [markdown]
# ### Concatenate Data Frames

# %%
import pandas as pd
india_weather = pd.DataFrame({
    'city':['mumbai','bangalore','delhi'],
    'temperature':[32,27,45],
    'humidity':[80,60,79]
})

india_weather
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1  bangalore           27        60
# 2      delhi           45        79

# %%
us_weather = pd.DataFrame({
    'city':['nyc','chicago','palo alto'],
    'temperature':[21,14,35],
    'humidity':[68,65,75]
})
us_weather
# Out:
#         city  temperature  humidity
# 0        nyc           21        68
# 1    chicago           14        65
# 2  palo alto           35        75

# %%
# concatenate two dataframes
df = pd.concat([india_weather , us_weather])
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1  bangalore           27        60
# 2      delhi           45        79
# 0        nyc           21        68
# 1    chicago           14        65
# 2  palo alto           35        75

# %%
# continuous index
df = pd.concat([india_weather , us_weather], ignore_index=True)
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1  bangalore           27        60
# 2      delhi           45        79
# 3        nyc           21        68
# 4    chicago           14        65
# 5  palo alto           35        75

# %%
df = pd.concat([india_weather,us_weather],axis=1)
df
# Out:
#         city  temperature  humidity       city  temperature  humidity
# 0     mumbai           32        80        nyc           21        68
# 1  bangalore           27        60    chicago           14        65
# 2      delhi           45        79  palo alto           35        75

# %% [markdown]
# ### Merge DataFrames

# %%
temperature_df = pd.DataFrame({
    'city':['mumbai','delhi','bangalore','hyderabad'],
    'temperature':[35,40,32,37]
})

temperature_df
# Out:
#         city  temperature
# 0     mumbai           35
# 1      delhi           40
# 2  bangalore           32
# 3  hyderabad           37

# %%
humdity_df = pd.DataFrame({
    'city':['delhi','mumbai','bangalore'],
    'humidity':[68,65,75]
})
humdity_df
# Out:
#         city  humidity
# 0      delhi        68
# 1     mumbai        65
# 2  bangalore        75

# %%
# merge two dataframes without explicitly mention index
df = pd.merge(temperature_df,humdity_df,on='city')
df
# Out:
#         city  temperature  humidity
# 0     mumbai           35        65
# 1      delhi           40        68
# 2  bangalore           32        75

# %%
# Outer-join
df = pd.merge(temperature_df,humdity_df,on='city',how='outer')
df
# Out:
#         city  temperature  humidity
# 0     mumbai           35      65.0
# 1      delhi           40      68.0
# 2  bangalore           32      75.0
# 3  hyderabad           37       NaN

# %% [markdown]
# ### Numerical Indexing

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([1,2,3,4,5,6,7,8,9,19], index=[49,48,47,46,45,1,2,3,4,5])
df
# Out:
#      0
# 49   1
# 48   2
# 47   3
# 46   4
# 45   5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   19

# %%
df.loc[:2]
# Out:
#     0
# 49  1
# 48  2
# 47  3
# 46  4
# 45  5
# 1   6
# 2   7

# %%
df.iloc[:2]
# Out:
#     0
# 49  1
# 48  2

# %%
df.loc[45]
# Out:
# 0    5
# Name: 45, dtype: int64

# %%
df.iloc[45]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1280/3269948178.py in <module>
# ----> 1 df.iloc[45]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
# ...
